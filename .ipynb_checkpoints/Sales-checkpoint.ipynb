# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sales.csv', encoding= 'ISO-8859-1')

# %%
df.head()
# Out:
#    Unnamed: 0              event_id        primary_act_id  \
# 0           1  abcaf1adb99a935fc661  43f0436b905bfa7c2eec
# 1           2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 2           3  c7ab4524a121f9d687d2  4b677c3f5bec71eec8d1
# 3           4  394cb493f893be9b9ed1  b1ccea01ad6ef8522796
# 4           5  55b5f67e618557929f48  91c03a34b562436efa3c
#
#        secondary_act_id   purch_party_lkup_id  \
# 0  b85143bf51323b72e53c  7dfa56dd7d5956b17587
# 1  f53529c5679ea6ca5a48  4f9e6fc637eaf7b736c2
# 2  b85143bf51323b72e53c  6c2545703bd527a7144d
# 3  b85143bf51323b72e53c  527d6b1eaffc69ddd882
# 4  b85143bf51323b72e53c  8bd62c394a35213bdf52
#
#                                           event_name  \
# 0  Xfinity Center Mansfield Premier Parking: Flor...
# 1      Gorge Camping - dave matthews band - sept 3-7
# 2        Dodge Theatre Adams Street Parking - benise
# 3  Gexa Energy Pavilion Vip Parking : kid rock wi...
# 4                      Premier Parking - motley crue
#
#                            primary_act_name  secondary_act_name  \
# 0  XFINITY Center Mansfield Premier Parking                 NaN
# 1                             Gorge Camping  Dave Matthews Band
# 2                             Parking Event                 NaN
# 3          Gexa Energy Pavilion VIP Parking                 NaN
# 4  White River Amphitheatre Premier Parking                 NaN
#
#   major_cat_name minor_cat_name  ... edu_1st_indv_val edu_2nd_indv_val  \
# 0           MISC        PARKING  ...              NaN              NaN
# 1           MISC        CAMPING  ...              NaN              NaN
# 2           MISC        PARKING  ...              NaN              NaN
# 3           MISC        PARKING  ...              NaN              NaN
# 4           MISC        PARKING  ...              NaN              NaN
#
#   adults_in_hh_num  married_ind  child_present_ind home_owner_ind occpn_val  \
# 0              NaN          NaN                NaN            NaN       NaN
# 1              NaN          NaN                NaN            NaN       NaN
# 2              NaN          NaN                NaN            NaN       NaN
# 3              NaN          NaN                NaN            NaN       NaN
# 4              NaN          NaN                NaN            NaN       NaN
#
#   occpn_1st_val occpn_2nd_val dist_to_ven
# 0           NaN           NaN         NaN
# 1           NaN           NaN        59.0
# 2           NaN           NaN         NaN
# 3           NaN           NaN         NaN
# 4           NaN           NaN         NaN
#
# [5 rows x 46 columns]

# %%
df.shape
# Out:
# (5000, 46)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 46 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              5000 non-null   int64
#  1   event_id                5000 non-null   object
#  2   primary_act_id          5000 non-null   object
#  3   secondary_act_id        5000 non-null   object
#  4   purch_party_lkup_id     5000 non-null   object
#  5   event_name              5000 non-null   object
#  6   primary_act_name        5000 non-null   object
#  7   secondary_act_name      1586 non-null   object
#  8   major_cat_name          5000 non-null   object
#  9   minor_cat_name          5000 non-null   object
#  10  la_event_type_cat       5000 non-null   object
#  11  event_disp_name         5000 non-null   object
#  12  ticket_text             5000 non-null   object
#  13  tickets_purchased_qty   5000 non-null   int64
#  14  trans_face_val_amt      5000 non-null   float64
#  15  delivery_type_cd        5000 non-null   object
#  16  event_date_time         5000 non-null   object
#  17  event_dt                5000 non-null   object
#  18  presale_dt              2108 non-null   object
#  19  onsale_dt               4899 non-null   object
#  20  sales_ord_create_dttm   4996 non-null   object
#  21  sales_ord_tran_dt       5000 non-null   object
#  22  print_dt                4576 non-null   object
#  23  timezn_nm               5000 non-null   object
#  24  venue_city              5000 non-null   object
#  25  venue_state             5000 non-null   object
#  26  venue_postal_cd_sgmt_1  5000 non-null   object
#  27  sales_platform_cd       2578 non-null   object
#  28  print_flg               5000 non-null   object
#  29  la_valid_tkt_event_flg  5000 non-null   object
#  30  fin_mkt_nm              5000 non-null   object
#  31  web_session_cookie_val  5000 non-null   object
#  32  gndr_cd                 177 non-null    object
#  33  age_yr                  168 non-null    float64
#  34  income_amt              154 non-null    float64
#  35  edu_val                 139 non-null    object
#  36  edu_1st_indv_val        112 non-null    object
#  37  edu_2nd_indv_val        86 non-null     object
#  38  adults_in_hh_num        176 non-null    float64
#  39  married_ind             157 non-null    float64
#  40  child_present_ind       130 non-null    float64
#  41  home_owner_ind          138 non-null    float64
#  42  occpn_val               79 non-null     object
#  43  occpn_1st_val           77 non-null     object
#  44  occpn_2nd_val           63 non-null     object
#  45  dist_to_ven             323 non-null    float64
# dtypes: float64(8), int64(2), object(36)
# memory usage: 1.8+ MB

# %%
#show some colunms have many Nan data 
df.isna().sum()
# Out:
# Unnamed: 0                   0
# event_id                     0
# primary_act_id               0
# secondary_act_id             0
# purch_party_lkup_id          0
# event_name                   0
# primary_act_name             0
# secondary_act_name        3414
# major_cat_name               0
# minor_cat_name               0
# la_event_type_cat            0
# event_disp_name              0
# ticket_text                  0
# tickets_purchased_qty        0
# trans_face_val_amt           0
# delivery_type_cd             0
# event_date_time              0
# event_dt                     0
# presale_dt                2892
# onsale_dt                  101
# sales_ord_create_dttm        4
# sales_ord_tran_dt            0
# print_dt                   424
# timezn_nm                    0
# venue_city                   0
# venue_state                  0
# venue_postal_cd_sgmt_1       0
# sales_platform_cd         2422
# print_flg                    0
# la_valid_tkt_event_flg       0
# fin_mkt_nm                   0
# web_session_cookie_val       0
# gndr_cd                   4823
# age_yr                    4832
# income_amt                4846
# edu_val                   4861
# edu_1st_indv_val          4888
# edu_2nd_indv_val          4914
# adults_in_hh_num          4824
# married_ind               4843
# child_present_ind         4870
# home_owner_ind            4862
# occpn_val                 4921
# occpn_1st_val             4923
# occpn_2nd_val             4937
# dist_to_ven               4677
# dtype: int64

# %%
cols=[]
for c in df.columns:
    cols.append(c)

# %%
#columns drop
df.drop(cols[32:],axis=1, inplace=True)

# %%
df.drop(['secondary_act_name','trans_face_val_amt','sales_platform_cd','presale_dt'],axis=1, inplace=True)

# %%
#handle nan value in print_dt and onsale_dt
df['print_dt'].fillna(df['print_dt'].mode(), inplace = True)
df['onsale_dt'].fillna(df['onsale_dt'].mode(),inplace=True)

# %%
#show sales_ord_tran_dt need to clean solit it to sales_day -sale_ moth -sales_year
#show print_dt need to clean
df.head()
# Out:
#    Unnamed: 0              event_id        primary_act_id  \
# 0           1  abcaf1adb99a935fc661  43f0436b905bfa7c2eec
# 1           2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 2           3  c7ab4524a121f9d687d2  4b677c3f5bec71eec8d1
# 3           4  394cb493f893be9b9ed1  b1ccea01ad6ef8522796
# 4           5  55b5f67e618557929f48  91c03a34b562436efa3c
#
#        secondary_act_id   purch_party_lkup_id  \
# 0  b85143bf51323b72e53c  7dfa56dd7d5956b17587
# 1  f53529c5679ea6ca5a48  4f9e6fc637eaf7b736c2
# 2  b85143bf51323b72e53c  6c2545703bd527a7144d
# 3  b85143bf51323b72e53c  527d6b1eaffc69ddd882
# 4  b85143bf51323b72e53c  8bd62c394a35213bdf52
#
#                                           event_name  \
# 0  Xfinity Center Mansfield Premier Parking: Flor...
# 1      Gorge Camping - dave matthews band - sept 3-7
# 2        Dodge Theatre Adams Street Parking - benise
# 3  Gexa Energy Pavilion Vip Parking : kid rock wi...
# 4                      Premier Parking - motley crue
#
#                            primary_act_name major_cat_name minor_cat_name  \
# 0  XFINITY Center Mansfield Premier Parking           MISC        PARKING
# 1                             Gorge Camping           MISC        CAMPING
# 2                             Parking Event           MISC        PARKING
# 3          Gexa Energy Pavilion VIP Parking           MISC        PARKING
# 4  White River Amphitheatre Premier Parking           MISC        PARKING
#
#   la_event_type_cat  ... sales_ord_tran_dt    print_dt  timezn_nm venue_city  \
# 0           PARKING  ...        2015-09-11  2015-09-12        EST  MANSFIELD
# 1           INVALID  ...        2009-07-05  2009-09-01        PST     QUINCY
# 2           PARKING  ...        2006-04-05  2006-04-05        MST    PHOENIX
# 3           PARKING  ...        2011-07-01  2011-07-06        CST     DALLAS
# 4           PARKING  ...        2005-06-18  2005-06-28        PST     AUBURN
#
#      venue_state venue_postal_cd_sgmt_1 print_flg la_valid_tkt_event_flg  \
# 0  MASSACHUSETTS                  02048        T                      N
# 1     WASHINGTON                  98848        T                      N
# 2        ARIZONA                  85003        T                      N
# 3          TEXAS                  75210        T                      N
# 4     WASHINGTON                  98092        T                      N
#
#   fin_mkt_nm web_session_cookie_val
# 0     Boston   7dfa56dd7d5956b17587
# 1    Seattle   4f9e6fc637eaf7b736c2
# 2    Arizona   6c2545703bd527a7144d
# 3     Dallas   527d6b1eaffc69ddd882
# 4    Seattle   8bd62c394a35213bdf52
#
# [5 rows x 28 columns]

# %%
#split sales_ord_tran_dt to three cpl
df[['Year_sales' , 'Month_sales','Day_sales']]=df.sales_ord_tran_dt.str.split('-', expand = True)

# %%
#split onsale_dt  to three cpl
df[['Year_onsale' , 'Month_onsale','Day_onsale']]=df.onsale_dt.str.split('-', expand = True)

# %%
#split sales_ord_create_dttm  to three cpl
df[['Year_create_dttm' , 'Month_create_dttm','Day_create_dttm']]=df.sales_ord_create_dttm.str.split('-', expand = True)

# %%
df[['Day_create_dttm' , 'time_create_dttm']]=df.Day_create_dttm.str.split(' ', expand = True)

# %%
lst1=['Year_sales' , 'Month_sales','Day_sales','Year_onsale' , 'Month_onsale','Day_onsale','Year_create_dttm' , 'Month_create_dttm','Day_create_dttm']

# %%
for x in lst1:
    df[x]= df[x].astype(float)

# %%
#Now drop sales_ord_tran_dt and  print_dt
df.drop(['sales_ord_tran_dt','onsale_dt' ,'sales_ord_create_dttm'],axis=1 , inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0              event_id        primary_act_id  \
# 0           1  abcaf1adb99a935fc661  43f0436b905bfa7c2eec
# 1           2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 2           3  c7ab4524a121f9d687d2  4b677c3f5bec71eec8d1
# 3           4  394cb493f893be9b9ed1  b1ccea01ad6ef8522796
# 4           5  55b5f67e618557929f48  91c03a34b562436efa3c
#
#        secondary_act_id   purch_party_lkup_id  \
# 0  b85143bf51323b72e53c  7dfa56dd7d5956b17587
# 1  f53529c5679ea6ca5a48  4f9e6fc637eaf7b736c2
# 2  b85143bf51323b72e53c  6c2545703bd527a7144d
# 3  b85143bf51323b72e53c  527d6b1eaffc69ddd882
# 4  b85143bf51323b72e53c  8bd62c394a35213bdf52
#
#                                           event_name  \
# 0  Xfinity Center Mansfield Premier Parking: Flor...
# 1      Gorge Camping - dave matthews band - sept 3-7
# 2        Dodge Theatre Adams Street Parking - benise
# 3  Gexa Energy Pavilion Vip Parking : kid rock wi...
# 4                      Premier Parking - motley crue
#
#                            primary_act_name major_cat_name minor_cat_name  \
# 0  XFINITY Center Mansfield Premier Parking           MISC        PARKING
# 1                             Gorge Camping           MISC        CAMPING
# 2                             Parking Event           MISC        PARKING
# 3          Gexa Energy Pavilion VIP Parking           MISC        PARKING
# 4  White River Amphitheatre Premier Parking           MISC        PARKING
#
#   la_event_type_cat  ... Year_sales Month_sales  Day_sales Year_onsale  \
# 0           PARKING  ...     2015.0         9.0       11.0      2015.0
# 1           INVALID  ...     2009.0         7.0        5.0      2009.0
# 2           PARKING  ...     2006.0         4.0        5.0      2006.0
# 3           PARKING  ...     2011.0         7.0        1.0      2011.0
# 4           PARKING  ...     2005.0         6.0       18.0      2005.0
#
#   Month_onsale Day_onsale Year_create_dttm Month_create_dttm Day_create_dttm  \
# 0          5.0       15.0           2015.0               9.0            11.0
# 1          3.0       13.0           2009.0               7.0             6.0
# 2          2.0       25.0           2006.0               4.0             5.0
# 3          4.0       22.0           2011.0               7.0             1.0
# 4          3.0        4.0           2005.0               6.0            18.0
#
#   time_create_dttm
# 0         18:17:45
# 1         00:00:00
# 2         00:00:00
# 3         17:38:50
# 4         00:00:00
#
# [5 rows x 35 columns]

# %%
import seaborn as sns
plt.figure(figsize=(10,15))
sns.heatmap(df.corr(),annot=True , square=True)

# %%
df.drop(['Year_onsale','Year_sales' ,'Day_sales','Month_sales'],axis=1 , inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              5000 non-null   int64
#  1   event_id                5000 non-null   object
#  2   primary_act_id          5000 non-null   object
#  3   secondary_act_id        5000 non-null   object
#  4   purch_party_lkup_id     5000 non-null   object
#  5   event_name              5000 non-null   object
#  6   primary_act_name        5000 non-null   object
#  7   major_cat_name          5000 non-null   object
#  8   minor_cat_name          5000 non-null   object
#  9   la_event_type_cat       5000 non-null   object
#  10  event_disp_name         5000 non-null   object
#  11  ticket_text             5000 non-null   object
#  12  tickets_purchased_qty   5000 non-null   int64
#  13  delivery_type_cd        5000 non-null   object
#  14  event_date_time         5000 non-null   object
#  15  event_dt                5000 non-null   object
#  16  print_dt                4576 non-null   object
#  17  timezn_nm               5000 non-null   object
#  18  venue_city              5000 non-null   object
#  19  venue_state             5000 non-null   object
#  20  venue_postal_cd_sgmt_1  5000 non-null   object
#  21  print_flg               5000 non-null   object
#  22  la_valid_tkt_event_flg  5000 non-null   object
#  23  fin_mkt_nm              5000 non-null   object
#  24  web_session_cookie_val  5000 non-null   object
#  25  Month_onsale            4899 non-null   float64
#  26  Day_onsale              4899 non-null   float64
#  27  Year_create_dttm        4996 non-null   float64
#  28  Month_create_dttm       4996 non-null   float64
#  29  Day_create_dttm         4996 non-null   float64
#  30  time_create_dttm        4996 non-null   object
# dtypes: float64(5), int64(2), object(24)
# memory usage: 1.2+ MB

# %%
#split event_date_time to three cpl
df[['Year_event_date_time' , 'Month_event_date_time','Day_event_date_time']]=df.event_date_time.str.split('-', expand = True)

# %%
#split Day_event_date_time to two cpl
df[['Day_event_date_time','event_time']]=df.event_date_time.str.split(' ',expand=True)

# %%
#split event_dt
df[['Year_event_dt' , 'Month_event_dt','Day_event_dt']]=df.event_dt.str.split('-', expand = True)

# %%
#split print_dt
df[['Year_print_dt','Month_print_dt','Day_print_dt']]=df.print_dt.str.split('-', expand = True)

# %%
# Out:
# 0       2015-09-11 18:17:45
# 1       2009-07-06 00:00:00
# 2       2006-04-05 00:00:00
# 3       2011-07-01 17:38:50
# 4       2005-06-18 00:00:00
#                ...
# 4995    2008-03-10 00:00:00
# 4996    2015-07-14 16:02:00
# 4997    2008-05-18 00:00:00
# 4998    2006-05-06 00:00:00
# 4999    2016-02-18 17:11:50
# Name: sales_ord_create_dttm, Length: 5000, dtype: object
